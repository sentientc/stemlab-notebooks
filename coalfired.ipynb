# %%
from IPython.core.display import Image, display

# %% [markdown]
# Health risk of Coal-fired power plant
# -------------
# 1. In addition to particulate matter(PM) emission, coal-fired power plant may emit a number of pollutants that is considered health risk(EH&E, 2011).
# 2. non-carcinogenic health risk from SO2 and Hg
# 3. carcinogenic health from As and Cr
# 4. Seleniosis risk from Se
# 5. Quality of coal affect emissions.
# 6. Health risk(non-carcinogenic) of PM is evaluated in terms of mortality(Penney, Bell, & Balbus, 2009).
# 7. PM2.5 dose response: 10 μg/m3 increase in ambient PM2.5 concentration was associated with approximately a 4% increased risk of all-cause mortality. A 6% increased risk of cardiopulmonary mortality and a 8% increased risk of lung cancer mortality for individuals 30 and older.

# %% [markdown]
# Comparison with Taipower health risk analysis(SINOTECH, 2015)
# -------------
# 1. PM2.5 health risk is similar to Penney et. al.(2009) with an extra anemic heart failure mortality
# 1. PM2.5 dose respone less than Penney et. al.(2009) which cited from research closer to Taiwan.
# 1. Simulated 12 pollutant dispersion with ISCST3 over 5 year(2009-2013)
# 1. ISCST3 generally give higher result than AERMOD.
# 1. CALPUFF simulate dispsersion to estimate derivative PM and terrain effect.

# %% [markdown]
# Summary to the references
# -----------
# 1. Kumar, R. (2012). Coal-fired Power Plant Risk Evaluation Strategy. IEEE-International Conference On Advances In Engineering, Science And Management
#   + General strategy for risk evaluation
# 2. Joode, J.D. & Boots, M.G. (2005) Concepts of Investment Risks and Strategies in Electricity Generation.
#   + Investment risks in electricity generation.
# 3. Ayfer Bartan, A., Kucukali, S., and Ar, I. (2017). Environmental impact assessment of coal power plants in operation. E3S Web of Conferences.
#   + Environmental impacts of coal-fired power plant
# 4. EH&E. (2011) Emissions of Hazardous Air Pollutants from Coal-fired Power Plants. Environmental Health & Engineering, Inc.

# %%
display(Image('figs/toxic.PNG', width=700, unconfined=True))

# %% [markdown]
# 5\. Penney, S., Bell, J., & Balbus, J. (2009). Estimating the Health Impacts of Coal-Fired Power Plants Receiving International. Financing. Environmental Defense Fund.
#   + Air Pollution Estimates(PM, SO2 and NOX emissions) were estimated by applying a table of electricity generating unit emission factors to reported plant-specific megawatt-hours generated per annum
#   + Estimation of Particulate Exposure to each plant’s emissions were estimated on global high-resolution maps.
#   + Estimation of Mortality Impacts using Concentration-response functions where 10 μg/m3 increase in ambient PM2.5 concentration was associated with approximately a 4% increased risk of all-cause mortality. A 6% increased risk of cardiopulmonary mortality and a 8% increased risk of lung cancer mortality for individuals 30 and older.

# %%
display(Image('figs/moti.PNG', width=700, unconfined=True))

# %% [markdown]
# 6\. Mokhtar, M. M., Hassim, M. H., & Taib, R.M. (2014). Health risk assessment of emissions from a coal-fired power plant using AERMOD modelling. Process Safety and Environmental Protection. 92: 476–485
#   + coal-fired power plants emit SOx, NOx, carbon dioxide (CO2), hydrogen fluoride (HF), hydrogen chloride (HCl), mercury (Hg) and dioxins. This health risk assessment(HRA) assess non-carcinogenic health risk from SO2 and Hg and carcinogenic health from As and Cr.

# %% [markdown]
# 7\. Bolten, J. G. et. al.(1987). Health risk of toxic emissions from a coal-fired power plant. Electric Power Research Institute.
#   + Assess chronic health risk of coal-fired power plant toxic emissions.
#   + Arsenic, beryllium and selenium concentrations in local rivers.
#   + Concentration analysis using surface water transport model.
#   + Exposure model utilise pathways from surface emission to consumption of water and fish from the affected waterways and consumption of milk, beef, pork, paultry, grain and vegetables produced from the affected water irrigated land.

# %% [markdown]
# 8\. Jozi, S. A. & Pouriyeh, A. A. (2011). Health-safety and environmental risk assessment of power plants using multi criteria decision making method. Association of the Chemical Engineers of Serbia.
#   + Assess environmental risk using emissions(CO2, CO, NOx ,and SO2), effluents(BOD, COD, DO, TDS, TSS and other pollutants), noise and vibration.
#   + Assess risk with analytical hierarchy process(AHP).  hierarchical structure of the risk is a variety of sub-criteria including health-safety risks, technological risks, and the affected environment risks. Each sub-criterion can further divided into the sub-sub-criteria. For example, safety and health risks include risks and diseases caused by thermal stress, hearing loss, skeleton and muscular disorders, skin and respiratory diseases, vision loss, accident, electric shock and illness resulting from exposure to magnetic field over a long term.
#   + 9 point judgment scale of Safety, one score was assigned to each pair-wise comparison of risks and effects. The Expert Choice software the relative importance of criteria were calculated and the weight of final risk was obtained by aggregating of multiplied criteria in options weight.

# %% [markdown]
# 9\. BARCLAYS (2015) Environmental and Social Risk Briefing: power generation. Barclays banks PLC.
#   + coal fired power stations the coal is pulverised (to enhance combustion efficiency), then fed into the combustion chamber of a boiler and burned. Advanced coal utilisation technology (e.g. fluidised bed combustion) tends to be more efficient than conventional and combined cycle systems. Integrated Coal Gasification Combined Cycle (IGCC) power plant is the most environmentally friendly coal-fired power generation technology. Most importantly, coal gasification offers the immediate opportunity to generate power with near zero greenhouse gas emissions and the pathway to a future hydrogen economy.
#   + There are limited alternatives to coal, technology should be installed to minimise emissions as much as possible.

# %% [markdown]
# 10\. TATA. (unknow year). EIA Report for 1000 MW Coal Based Thermal Power Plant at Naraj Marthapur, Cuttack, Orissa. The Tata Power Company Ltd.
#   + Fuel oil and chlorine are the major accident hazards(MAH) that in excess of the threshold quantities of the local regulation,

# %% [markdown]
# 11\. Unknow source 1. RISK ASSESSMENT AND RISK MANAGEMENT PLAN. Jamshoro Power Generation Project
#   + Using below-specification coal would degrade the unit and decrease efficiency.

# %% [markdown]
# 12\. Charalampous, G. & Madlener, R.(2013). Risk Management and Portfolio Optimization for Gas- and Coal-Fired Power Plants in Germany: A Multivariate GARCH Approach. Institute for Future Energy Consumer Needs and Behavior.
#   + risk management in the German power market by assess and choose the optimum forward contract for hedging the power output and fuel purchase simultaneously.
#   + coal-fired power plants seem profitable because imported coal prices fell dramatically and decreasing emission allowance prices in the EU-ETS.

# %% [markdown]
# 13\. Unknow source 2. Risk Assessment Studies
#   +  Natural Hazards, Major Chemical Hazards, Fire Hazards and so on.

# %% [markdown]
# 14\. Berry, D. (2008). Investment Risk of New Coal-Fired Power Plants. Western Resource Advocates.
#   + Investment risks in construction cost, Fuel cost, and greenhouse gas emission regulation
#   + Coal-fired power plants are relatively expensive to build, but generally have low fuel costs.

# %% [markdown]
# 15\. Sinotech. (2015). Health risk evaluation and epidemiology baseline study of Da-lin power plant modification plan, Taipower
#   + Evalute the health risk of pollutant in IARC groups
#     + group 1: Cd, Cr(VI), Ni, As, Be, dioxin, PM2.5
#     + group 2: Pb, Sb, Co
#     + group 3: Se, Hg
#   + Carcigenic and non-carcigenic Health risks
#   + Total cancer risk is the sum of cancer risks from carcigens through various pathways
#   + Non-carcigenic risk is daily average exposure/reference dosage and sum of non-carcigenic rick is the total non-carcigenic risk.
#   + Include stack emission measurement from existing generator

# %%
display(Image('figs/moti_rev.PNG', width=700, unconfined=True))

# %%
display(Image('figs/moti_res.PNG', width=700, unconfined=True))
